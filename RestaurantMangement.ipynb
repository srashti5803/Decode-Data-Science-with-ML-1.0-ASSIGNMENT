# %%
# 6.
#Write a code for Restaurant Management System Using OO4S3
# & Create a MenuItem 'lass that has attributes su'h as name, des'ription, pri'e, and 'ategory
# & Implement methods to add a new menu item, update menu item information, and remove a menu item 
# from the menu
# & Use en'apsulation to hide the menu item's unique identifi'ation number
# & Inherit from the MenuItem 'lass to 'reate a FoodItem 'lass and a BeverageItem 'lass, ea'h with their own 
# spe'ifi' attributes and methods.



class MenuItem:
    def __init__(self, name, description, price, category):
        self.__name = name
        self.__description = description
        self.__price = price
        self.__category = category
        self.__id = id(self)  # Unique identification number using object's id

    def get_name(self):
        return self.__name

    def get_description(self):
        return self.__description

    def get_price(self):
        return self.__price

    def get_category(self):
        return self.__category

    def update_information(self, name=None, description=None, price=None, category=None):
        if name:
            self.__name = name
        if description:
            self.__description = description
        if price:
            self.__price = price
        if category:
            self.__category = category

    def display_info(self):
        print(f"Name: {self.__name}")
        print(f"Description: {self.__description}")
        print(f"Price: ${self.__price}")
        print(f"Category: {self.__category}")

        
        
class FoodItem(MenuItem):
    def __init__(self, name, description, price, category, cuisine_type):
        super().__init__(name, description, price, category)
        self.__cuisine_type = cuisine_type

    def get_cuisine_type(self):
        return self.__cuisine_type

    def update_information(self, name=None, description=None, price=None, category=None, cuisine_type=None):
        super().update_information(name, description, price, category)
        if cuisine_type:
            self.__cuisine_type = cuisine_type

    def display_info(self):
        super().display_info()
        print(f"Cuisine Type: {self.__cuisine_type}")


class BeverageItem(MenuItem):
    def __init__(self, name, description, price, category, beverage_type):
        super().__init__(name, description, price, category)
        self.__beverage_type = beverage_type

    def get_beverage_type(self):
        return self.__beverage_type

    def update_information(self, name=None, description=None, price=None, category=None, beverage_type=None):
        super().update_information(name, description, price, category)
        if beverage_type:
            self.__beverage_type = beverage_type

    def display_info(self):
        super().display_info()
        print(f"Beverage Type: {self.__beverage_type}")

        
        
# Test the Restaurant Management System
if __name__ == "__main__":
    # Create a FoodItem
    food_item = FoodItem("Spaghetti Carbonara", "Pasta with creamy sauce and bacon", 15.99, "Main Dish", "Italian")
    food_item.display_info()

    print("\nUpdating Food Item Information:")
    food_item.update_information(price=17.99, cuisine_type="Italian Fusion")
    food_item.display_info()

    print("\n")

    # Create a BeverageItem
    beverage_item = BeverageItem("Coca-Cola", "Refreshing soda", 2.49, "Beverage", "Soft Drink")
    beverage_item.display_info()

    print("\nUpdating Beverage Item Information:")
    beverage_item.update_information(description="Classic soft drink", price=1.99)
    beverage_item.display_info()
# Out:
# Name: Spaghetti Carbonara
# Description: Pasta with creamy sauce and bacon
# Price: $15.99
# Category: Main Dish
# Cuisine Type: Italian
#
# Updating Food Item Information:
# Name: Spaghetti Carbonara
# Description: Pasta with creamy sauce and bacon
# Price: $17.99
# Category: Main Dish
# Cuisine Type: Italian Fusion
#
#
# Name: Coca-Cola
# Description: Refreshing soda
# Price: $2.49
# Category: Beverage
# Beverage Type: Soft Drink
#
# Updating Beverage Item Information:
# Name: Coca-Cola
# Description: Classic soft drink
# Price: $1.99
# Category: Beverage
# Beverage Type: Soft Drink
